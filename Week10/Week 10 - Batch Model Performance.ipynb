# %%
# %run batch_data_science.ipynb
# Out:
# Trained Model Test Data Accuracy Score : 50.24999999999999
#
#               precision    recall  f1-score   support
#
#        False       0.50      0.51      0.50       197
#         True       0.51      0.49      0.50       203
#
#     accuracy                           0.50       400
#    macro avg       0.50      0.50      0.50       400
# weighted avg       0.50      0.50      0.50       400
# Trained Model Test Data Accuracy Score : 90.5
#
#               precision    recall  f1-score   support
#
#        False       0.91      0.89      0.90       197
#         True       0.90      0.92      0.91       203
#
#     accuracy                           0.91       400
#    macro avg       0.91      0.90      0.90       400
# weighted avg       0.91      0.91      0.90       400
# Trained Model Test Data Accuracy Score : 90.60000000000001
#
#               precision    recall  f1-score   support
#
#        False       0.92      0.89      0.91       503
# ...

# %%
#graph that demonstrates the steps: Dummy, KNN Training, KNN Prediction, KNN Retraining, KNN Retrained Prediction
#in the batch model performance with respect to accuracy, recall, precision for those steps
steps = ['Dummy', 'KNN Training', 'KNN Prediction', 'KNN Retraining', 'KNN Retrained Prediction']
accuracy = [result_scores['Dummy'][1], result_scores['KNN-1'][1], result_scores['KNN-2'][1], result_scores['KNN-3-1'][1], result_scores['KNN-3-2'][1]]
recall = [result_scores['Dummy'][2], result_scores['KNN-1'][2], result_scores['KNN-2'][2], result_scores['KNN-3-1'][2], result_scores['KNN-3-2'][2]]
precision = [result_scores['Dummy'][3], result_scores['KNN-1'][3], result_scores['KNN-2'][3], result_scores['KNN-3-1'][3], result_scores['KNN-3-2'][3]]
plt.figure(figsize=(10, 6))
plt.plot(steps, accuracy, marker='o', label='Accuracy', linewidth=2)
plt.plot(steps, recall, marker='s', label='Recall', linewidth=2)
plt.plot(steps, precision, marker='^', label='Precision', linewidth=2)
plt.title('Model Performance Over Batch Processing Steps')
plt.xlabel('Processing Step')
plt.ylabel('Score')
plt.ylim(0, 1.05)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()
